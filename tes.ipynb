# %%
from PIL import Image
img = Image.open('dog.webp') #C:\Users\ifoa\Desktop\Nuova cartella\dog.webp path assoluto dog.webp path relativo
img
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=768x432>
